# %% [markdown]
# # Exploration and Data Collection
#
# In this notebook, the first stage of initial data-exploration is carried out:
#
# * We count time phrases in the Hebrew Bible and see which ones are the most common.
# * We make counts of the verb tenses and their percentages as used within single time phrase markers.
# * Finally, we export a dataset with pickle for processing in further notebooks.
#
# This notebook finds some initial corrolations between certain time phrases and the tenses used alongside them. See the interesting comparison between the phrase עד היום הזה (wayyiqtol prominent!) and עד עולם (yiqtol prominent). Other time markers also prefer yiqtol over wayyiqtol or vice versa.

# %%
# import tools
import collections, matplotlib, pickle
import pandas as pd
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline
import numpy as np
from numpy.random import rand
from pprint import pprint

from tf.fabric import Fabric

# %%
# initialize and load TF and data

TF = Fabric(modules=['hebrew/etcbc4c', 'hebrew/phono'], silent=True)

api = TF.load('''
                language book chapter verse
                g_cons lex
                function vt kind pdp typ
                mother tab domain code
                g_cons_utf8 phono
              ''')

api.makeAvailableIn(globals())
# Out:
#   0.00s loading features ...
#    |     0.05s B book                 from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B chapter              from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.01s B verse                from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.33s B g_cons               from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.26s B g_cons_utf8          from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.27s B phono                from /Users/Cody/github/text-fabric-data/hebrew/phono
#    |     0.15s B language             from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.18s B lex                  from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.12s B function             from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.19s B vt                   from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.04s B kind                 from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.17s B pdp                  from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.27s B typ                  from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.28s B mother               from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.02s B tab                  from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.03s B domain               from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.04s B code                 from /Users/Cody/github/text-fabric-data/hebrew/etcbc4c
#    |     0.00s Feature overview: 105 for nodes; 5 for edges; 2 configs; 7 computed
#   9.21s All features loaded/computed - for details use loadLog()

# %%
# import custom function for weqetal detection
from functions.verbs import is_weqt

# %% [markdown]
# ## Clause Level: Tense and Time Markers
#
# Before gathering data at the text level for verbal tense, we will look for tendencies at the clause level. It is intended that the information gathered at clause level can be compared with that from the text level, which in turn can help with the question of whether tense selection can really be influenced by a time marker in another clause. In other words, if the same kinds of tendencies that affect the verbal tense at clause level appear at text level, the case for "time spans" is strengthened.
#
# We begin with some preliminary data-exploration.
#
# ## 1. Survey Time Markers in Verbal Clauses
#
# How many different time markers appear in verbal clauses? What are the most common ones? How diverse are they?

# %%
# count time markers
time_markers = collections.defaultdict(list)

# count clauses with multiple time markers
multiples = []

# get time markers from clauses
for clause in F.otype.s('clause'):
    
    # skip clause if not Hebrew
    language = F.language.v(L.d(clause, otype='word')[0])
    if language != 'hbo':
        continue
    
    # skip clause if not verbal
    if F.kind.v(clause) != 'VC':
        continue
        
    times = [time_phrase for time_phrase in L.d(clause, otype='phrase')
                if F.function.v(time_phrase) == 'Time']
    
    # skip clause if there are no time phrases
    if not times:
        continue
        
    # treat multiple time markers separately
    if len(times) > 1:
        multiples.append(clause)
        
    # measure and save other time markers
    else:
        
        # isolate time marker
        marker = times[0]
        
        # get plain-text for the time marker
        consonantal_words = tuple(F.g_cons.v(word) for word in L.d(marker, otype='word'))
        marker_text = ' '.join(consonantal_words)
        
        # save marker and clause node
        time_markers[marker_text].append(clause)
        
# make/present counts

# keep count here
initial_counts = collections.Counter()

# count them
for marker, clause_list in time_markers.items():
    initial_counts[marker] += len(clause_list)
    
# various counts  
top_markers = initial_counts.most_common(50)
top_total = sum(count for marker, count in top_markers)
init_counts_total = sum(initial_counts.values())
    
# put counts into pandas dataframe

initial_dataframe = pd.DataFrame(top_markers, columns=('Markers', 'Counts'))

print('Clauses with single marker: ', init_counts_total)
print('Clauses with multiple markers: ', len(multiples))
# Out:
# Clauses with single marker:  3102
# Clauses with multiple markers:  109

# %%
print('total top 50: ', top_total)
print('\t\t({}% of all...)'.format(round(top_total/init_counts_total, 2) * 100))
print('total types: ', len(initial_counts.keys()))

initial_dataframe
# Out:
# total top 50:  1651
# 		(53.0% of all...)
# total types:  985
#              Markers  Counts
# 0       B  JWM H HW>     198
# 1              H JWM     160
# 2                <TH      78
# 3             B  BQR      76
# 4             L <WLM      76
# 5      <D H JWM H ZH      58
# 6                 >Z      57
# 7          CB<T JMJM      56
# 8              B JWM      53
# 9            <D <WLM      45
# 10           >XRJ KN      44
# 11          <D H <RB      41
# 12         KL H JMJM      38
# 13       B  <T H HJ>      36
# 14              LJLH      33
# 15    B  JWM H CBJ<J      32
# 16               >XR      31
# 17          KL H JWM      31
# 18               MXR      28
# 19        H JWM H ZH      26
# 20             L NYX      24
# 21              TMJD      23
# 22        >RB<JM CNH      22
# 23    B  JWM H CLJCJ      21
# 24            H LJLH      20
# 25             >XRJW      20
# 26            <D MTJ      19
# 27      B  JMJM H HM      18
# 28            M MXRT      18
# 29       B  <T H HW>      18
# 30            B  <RB      17
# 31         JMJM RBJM      16
# 32     B  LJLH H HW>      15
# 33              JWMM      15
# 34       JWMM W LJLH      14
# 35          CCT JMJM      14
# 36  B <YM H JWM H ZH      13
# 37            B JMJW      12
# 38           B  LJLH      12
# 39    B >XRJT H JMJM      12
# 40            <D >NH      12
# 41           B KL <T      12
# 42    B  JWM H CMJNJ      12
# 43             L <LM      11
# 44          CB< CNJM      11
# 45          B  YHRJM      11
# 46           CC CNJM      11
# 47              L <D      11
# 48         CLCT JMJM      10
# 49            <D BQR      10

# %% [markdown]
# Notes:
#
# 1. prepositions denoting position: e.g. <D, B, L, M, >XR, >Z
# 2. nouns denoting time/event: JWM, <TH, BQR, <WLM, <RB, MXR, LJLH,
# 3. words denoting quantity: KL, numbers
# 4. word denoting extent: <D
# 5. the role of article/demonstratives in indicating distance: H, ZH, HW>, HM, HJ>
#
# ## 2. Corrolate Time Markers with Verb Tense
#
# Now we take the registered time markers in the `time_markers` dict and use the list values (which contain the clause node numbers) to gather verb tense statistics.

# %%
def get_verb(clause):
    '''
    Extract and return a word node 
    that functions as the primary verb.
    Require a clause node.
    '''

    # set of predicative phrase functions
    # derived from a small query
    predicates = {'Pred', 'PreO', 'PreS','PreC','PtcO'}

    # get the main verb
    verb = [word for phrase in L.d(clause, otype='phrase')
                for word in L.d(phrase, otype='word')

                 # phrase must be predicate; word functions as verb
                 if F.function.v(phrase) in predicates
                    and F.pdp.v(word) == 'verb'
            ]

    # account for clauses with both Pred and PreC, take only Pred
    if len(verb) > 1:
        verb = [word for word in verb 
                    if F.function.v(L.u(word, otype='phrase')[0]) == 'Pred']

    return verb[0]

# %% [markdown]
# ### 2.1. Count Tenses and Sort Clause Lists by Tenses/Time Markers

# %%
# hold verbs & verb stats here
tense_counts = collections.defaultdict(lambda: collections.Counter())
tenses = collections.defaultdict(lambda: collections.defaultdict(list))

# count verbs
for time_marker, clause_list in time_markers.items():
    
    for clause in clause_list:

        verb = get_verb(clause)
        
        # get the verb's tense
        tense = F.vt.v(verb)
        
        # register weqetal separately from qatal
        tense = 'weqt' if is_weqt(verb) else tense
        
        # save the data to the time marker key
        tense_counts[time_marker][tense] += 1
        tense_counts[time_marker]['total'] += 1
        
        # save the clause under its corresponding verb tense
        tenses[time_marker][tense].append(clause) 
        
print('done with counts...\n')
# Out:
# done with counts...

# %%
pprint(tenses['L NYX'])
# Out:
# defaultdict(<class 'list'>,
#             {'impf': [457153,
#                       468108,
#                       469177,
#                       469638,
#                       471993,
#                       473060,
#                       478514,
#                       486101,
#                       489450,
#                       491248,
#                       491432,
#                       491614,
#                       492313,
#                       493112,
#                       493644,
#                       494187,
#                       496701,
#                       497404,
#                       497747,
#                       497993],
#              'perf': [468898, 489414, 489497, 492876]})

# %%
# make percentage counts for all time markers and their verbs

# get all the tenses to fill in zero counts
all_tenses = sorted(tense for tense, value in F.vt.freqList())
all_tenses.remove('NA') # don't count this
all_tenses.append('weqt') # add custom weqetal tense

# put the percentage counts here
tense_percentages = {}

# make % counts based on verb_counts
for time_marker, counts in tense_counts.items():
    
    # make percentage counts; exclude "total" from percentage counts
    total = counts['total']
    percentages = dict((tense, (count/total)*100) for tense, count in counts.items()
                          if tense != 'total'
                      )
    
    # fill in any empty tense slots
    all_percentages = dict((tense, percentages.get(tense, 0)) for tense in all_tenses)
    
    # save the count
    tense_percentages[time_marker] = all_percentages

# check results
print(len(tense_percentages), 'percentages counted\n')
print('Sample: ')
pprint(tense_percentages['>Z'])
# Out:
# 985 percentages counted
#
# Sample:
# {'impf': 68.42105263157895,
#  'impv': 0,
#  'infa': 0,
#  'infc': 0,
#  'perf': 29.82456140350877,
#  'ptca': 1.7543859649122806,
#  'ptcp': 0,
#  'wayq': 0,
#  'weqt': 0}

# %%
# fill in any blank slots for verb counts and verbs (counts, not percentages)

# counts
for marker, counts in tense_counts.items():
    counts = dict((tense, counts.get(tense, 0)) for tense in all_tenses)
    tense_counts[marker] = counts
    
# verbs
for marker, tense_dict in tenses.items():
    tense_dict = dict((tense, tense_dict.get(tense, [])) for tense in all_tenses)
    tenses[marker] = tense_dict
    
print('Sample:')
pprint(tense_counts['L NYX'])
print()
pprint(tenses['L NYX'])
# Out:
# Sample:
# {'impf': 20,
#  'impv': 0,
#  'infa': 0,
#  'infc': 0,
#  'perf': 4,
#  'ptca': 0,
#  'ptcp': 0,
#  'wayq': 0,
#  'weqt': 0}
#
# {'impf': [457153,
#           468108,
#           469177,
#           469638,
#           471993,
#           473060,
#           478514,
#           486101,
#           489450,
#           491248,
#           491432,
#           491614,
#           492313,
#           493112,
#           493644,
#           494187,
#           496701,
#           497404,
#           497747,
#           497993],
#  'impv': [],
#  'infa': [],
#  'infc': [],
#  'perf': [468898, 489414, 489497, 492876],
#  'ptca': [],
#  'ptcp': [],
#  'wayq': [],
#  'weqt': []}

# %% [markdown]
# ### 3. Analyze Initial Results with Visualizations

# %%
# Collect/display stats
    
# a header for the pandas table
header = ['marker', 'occur'] + all_tenses

# holds rows for the table
stats_rows = []

# to reproduce row data for later visualizations
stats_dict = {'header': header}

# display the counts using top 50 order
for marker, count in initial_counts.items():

    count = initial_counts[marker]
    
    # collect percentages/counts in sorted order of tense name
    percentages = ['{}%'.format(round(count, 1)) for tense, count 
                       in sorted(tense_percentages[marker].items())]
    
    counts = [count for tense, count in sorted(tense_counts[marker].items())]
    
    # combine percentages/stats into individual strings
    stats = ['{} ({})'.format(percent, count) for percent, count in zip(percentages, counts)]
    
    row = [marker, count] + stats
    
    # add row data
    
    # add only top 50 for this display
    if (marker, count) in top_markers:
        stats_rows.append((count, row))
    
    # add all row data for later
    stats_dict[marker] = row
    

# get sorting for visualization below
sort_top_rows = [row[1] for row in sorted(stats_rows, reverse=True)]
    
verb_counts_df = pd.DataFrame(sort_top_rows, columns=header)

# %%
verb_counts_df
# Out:
#               marker  occur        impf       impv      infa        infc  \
# 0       B  JWM H HW>    198  29.3% (58)     0% (0)    0% (0)    0.5% (1)
# 1              H JWM    160  15.0% (24)   3.8% (6)    0% (0)    5.0% (8)
# 2                <TH     78  50.0% (39)   9.0% (7)    0% (0)      0% (0)
# 3             L <WLM     76  60.5% (46)   3.9% (3)    0% (0)    7.9% (6)
# 4             B  BQR     76  13.2% (10)  10.5% (8)  1.3% (1)    3.9% (3)
# 5      <D H JWM H ZH     58    5.2% (3)     0% (0)    0% (0)    1.7% (1)
# 6                 >Z     57  68.4% (39)     0% (0)    0% (0)      0% (0)
# 7          CB<T JMJM     56  46.4% (26)   1.8% (1)    0% (0)      0% (0)
# 8              B JWM     53  30.2% (16)   3.8% (2)    0% (0)    3.8% (2)
# 9            <D <WLM     45  48.9% (22)   2.2% (1)    0% (0)   11.1% (5)
# 10           >XRJ KN     44  36.4% (16)     0% (0)    0% (0)      0% (0)
# 11          <D H <RB     41  29.3% (12)     0% (0)    0% (0)      0% (0)
# 12         KL H JMJM     38   21.1% (8)     0% (0)    0% (0)  26.3% (10)
# 13       B  <T H HJ>     36  30.6% (11)     0% (0)    0% (0)    2.8% (1)
# 14              LJLH     33    6.1% (2)   3.0% (1)    0% (0)    3.0% (1)
# 15    B  JWM H CBJ<J     32  31.2% (10)     0% (0)    0% (0)      0% (0)
# 16          KL H JWM     31   29.0% (9)   3.2% (1)    0% (0)    6.5% (2)
# 17               >XR     31  67.7% (21)     0% (0)    0% (0)      0% (0)
# 18               MXR     28  64.3% (18)  17.9% (5)    0% (0)      0% (0)
# 19        H JWM H ZH     26   26.9% (7)   3.8% (1)    0% (0)      0% (0)
# 20             L NYX     24  83.3% (20)     0% (0)    0% (0)      0% (0)
# 21              TMJD     23   34.8% (8)   8.7% (2)    0% (0)   13.0% (3)
# 22        >RB<JM CNH     22   22.7% (5)     0% (0)    0% (0)    4.5% (1)
# 23    B  JWM H CLJCJ     21   33.3% (7)   4.8% (1)    0% (0)    4.8% (1)
# 24            H LJLH     20   25.0% (5)  15.0% (3)    0% (0)      0% (0)
# 25             >XRJW     20    5.0% (1)     0% (0)    0% (0)      0% (0)
# 26            <D MTJ     19  78.9% (15)     0% (0)    0% (0)      0% (0)
# 27            M MXRT     18      0% (0)     0% (0)    0% (0)      0% (0)
# 28      B  JMJM H HM     18   22.2% (4)     0% (0)    0% (0)      0% (0)
# 29       B  <T H HW>     18      0% (0)     0% (0)    0% (0)      0% (0)
# 30            B  <RB     17   23.5% (4)     0% (0)    0% (0)    5.9% (1)
# 31         JMJM RBJM     16   31.2% (5)     0% (0)    0% (0)      0% (0)
# 32              JWMM     15   46.7% (7)     0% (0)    0% (0)   13.3% (2)
# 33     B  LJLH H HW>     15      0% (0)     0% (0)    0% (0)      0% (0)
# 34       JWMM W LJLH     14   42.9% (6)   7.1% (1)    0% (0)   21.4% (3)
# 35          CCT JMJM     14  71.4% (10)     0% (0)    0% (0)      0% (0)
# 36  B <YM H JWM H ZH     13   23.1% (3)     0% (0)    0% (0)      0% (0)
# 37           B KL <T     12   33.3% (4)   8.3% (1)    0% (0)      0% (0)
# 38            B JMJW     12   41.7% (5)     0% (0)    0% (0)      0% (0)
# 39    B >XRJT H JMJM     12   41.7% (5)     0% (0)    0% (0)      0% (0)
# 40           B  LJLH     12   33.3% (4)     0% (0)    0% (0)      0% (0)
# 41    B  JWM H CMJNJ     12   66.7% (8)     0% (0)    0% (0)      0% (0)
# 42            <D >NH     12   75.0% (9)     0% (0)    0% (0)      0% (0)
# 43             L <LM     11   36.4% (4)     0% (0)    0% (0)   18.2% (2)
# 44              L <D     11   81.8% (9)     0% (0)    0% (0)      0% (0)
# 45           CC CNJM     11   36.4% (4)     0% (0)    0% (0)      0% (0)
# 46          CB< CNJM     11   18.2% (2)     0% (0)    0% (0)      0% (0)
# 47          B  YHRJM     11   45.5% (5)     0% (0)    0% (0)    9.1% (1)
# 48         CLCT JMJM     10      0% (0)  10.0% (1)    0% (0)   10.0% (1)
# 49            <D BQR     10   70.0% (7)     0% (0)    0% (0)      0% (0)
#
#           perf        ptca      ptcp         wayq        weqt
# 0   14.1% (28)    2.0% (4)    0% (0)   31.8% (63)  22.2% (44)
# 1   35.0% (56)  30.0% (48)    0% (0)    7.5% (12)    3.8% (6)
# 2   37.2% (29)    1.3% (1)  2.6% (2)       0% (0)      0% (0)
# 3    11.8% (9)    3.9% (3)  2.6% (2)     2.6% (2)    6.6% (5)
# 4     2.6% (2)    3.9% (3)    0% (0)   55.3% (42)    9.2% (7)
# 5   29.3% (17)    3.4% (2)    0% (0)   60.3% (35)      0% (0)
# 6   29.8% (17)    1.8% (1)    0% (0)       0% (0)      0% (0)
# 7     1.8% (1)      0% (0)    0% (0)   19.6% (11)  30.4% (17)
# 8   41.5% (22)      0% (0)    0% (0)    15.1% (8)    5.7% (3)
# 9     6.7% (3)    6.7% (3)    0% (0)     4.4% (2)   20.0% (9)
# 10  22.7% (10)      0% (0)    0% (0)   40.9% (18)      0% (0)
# 11    2.4% (1)      0% (0)    0% (0)    14.6% (6)  53.7% (22)
# 12   13.2% (5)    2.6% (1)    0% (0)    10.5% (4)  26.3% (10)
# 13  27.8% (10)    5.6% (2)    0% (0)   30.6% (11)    2.8% (1)
# 14   15.2% (5)   12.1% (4)    0% (0)   54.5% (18)    6.1% (2)
# 15    6.2% (2)      0% (0)    0% (0)   31.2% (10)  31.2% (10)
# 16  38.7% (12)   16.1% (5)    0% (0)     6.5% (2)      0% (0)
# 17  32.3% (10)      0% (0)    0% (0)       0% (0)      0% (0)
# 18      0% (0)    7.1% (2)  3.6% (1)       0% (0)    7.1% (2)
# 19  53.8% (14)    3.8% (1)    0% (0)     3.8% (1)    7.7% (2)
# 20   16.7% (4)      0% (0)    0% (0)       0% (0)      0% (0)
# 21    4.3% (1)   17.4% (4)    0% (0)       0% (0)   21.7% (5)
# 22  45.5% (10)      0% (0)    0% (0)    27.3% (6)      0% (0)
# 23      0% (0)    4.8% (1)    0% (0)   47.6% (10)    4.8% (1)
# 24   30.0% (6)   10.0% (2)    0% (0)    15.0% (3)    5.0% (1)
# 25  75.0% (15)      0% (0)    0% (0)    20.0% (4)      0% (0)
# 26   10.5% (2)   10.5% (2)    0% (0)       0% (0)      0% (0)
# 27      0% (0)      0% (0)    0% (0)  100.0% (18)      0% (0)
# 28   50.0% (9)   11.1% (2)    0% (0)    16.7% (3)      0% (0)
# 29   33.3% (6)    5.6% (1)    0% (0)   61.1% (11)      0% (0)
# 30   11.8% (2)   11.8% (2)    0% (0)    41.2% (7)    5.9% (1)
# 31    6.2% (1)    6.2% (1)    0% (0)    56.2% (9)      0% (0)
# 32   13.3% (2)   13.3% (2)    0% (0)     6.7% (1)    6.7% (1)
# 33   13.3% (2)    6.7% (1)    0% (0)   80.0% (12)      0% (0)
# 34    7.1% (1)      0% (0)    0% (0)     7.1% (1)   14.3% (2)
# 35   21.4% (3)      0% (0)    0% (0)     7.1% (1)      0% (0)
# 36   38.5% (5)      0% (0)    0% (0)    30.8% (4)    7.7% (1)
# 37   16.7% (2)   33.3% (4)    0% (0)       0% (0)    8.3% (1)
# 38   58.3% (7)      0% (0)    0% (0)       0% (0)      0% (0)
# 39   16.7% (2)      0% (0)    0% (0)       0% (0)   41.7% (5)
# 40   16.7% (2)    8.3% (1)    0% (0)    41.7% (5)      0% (0)
# 41    8.3% (1)      0% (0)    0% (0)    16.7% (2)    8.3% (1)
# 42   16.7% (2)    8.3% (1)    0% (0)       0% (0)      0% (0)
# 43      0% (0)      0% (0)    0% (0)       0% (0)   45.5% (5)
# 44      0% (0)   18.2% (2)    0% (0)       0% (0)      0% (0)
# 45   18.2% (2)    9.1% (1)    0% (0)    18.2% (2)   18.2% (2)
# 46   27.3% (3)      0% (0)    0% (0)    45.5% (5)    9.1% (1)
# 47    9.1% (1)      0% (0)    0% (0)    18.2% (2)   18.2% (2)
# 48   20.0% (2)      0% (0)    0% (0)    50.0% (5)   10.0% (1)
# 49   10.0% (1)   10.0% (1)    0% (0)    10.0% (1)      0% (0)

# %% [markdown]
# ### 3.1. Some Interesting Results
#
# Both of the following time markers begin with the preposition עד, but one is *wayyiqtol* predominant and the other is *yiqtol* predominant.

# %%
# put tense/counts into dataframe for plotting
until_today = pd.Series(tense_counts['<D H JWM H ZH'], index=all_tenses)
until_forever = pd.Series(tense_counts['<D <WLM'], index=all_tenses)

# display plot
until_today.plot.bar(figsize=(6,6), 
                       color='teal', 
                       width = .8,
                       fontsize=18,
                       title = 'ʿad hayôm hazeh (58 occurrences)'
                    )

# save to file
plt.savefig('visualizations/until_today.png', dpi = 300)

# %%
# display plot
until_forever.plot.bar(figsize=(6,6), 
                       color='teal', 
                       width=.8,
                       fontsize=18,
                       title='ʿad ʿôlām (45 occurrences)'
                      )
# save to file
plt.savefig('visualizations/until_forever.png', dpi = 300)

# %%
round(tense_percentages['<D H JWM H ZH']['impf'])
# Out:
# 5

# %%
round(tense_percentages['<D H JWM H ZH']['wayq'])
# Out:
# 60

# %% [markdown]
# ## 4. Export Data
#
# This data, especially the full table/counts above, provides an apt starting point for further lines of questioning. But much more inquiry is required to determine what factors play a role in determining a time marker's tense. The data is gathered together into a single dict for further analysis in other notebooks.

# %%
# put all export data here
time_marker_data = {'markers':{}}

# keep top markers dict
time_marker_data['top_markers'] = top_markers

# keep the stats rows
time_marker_data['stats_rows'] = stats_dict

# assemble data from various dicts in this notebook
for marker, clause_list in time_markers.items():
    
    # retrieve
    count = len(clause_list)
    tense_to_clause = tenses[marker]
    tense_cts = tense_counts[marker]
    tense_pct = tense_percentages[marker]
    #representative time marker – allows for preposition search, etc. with TF objs
    example_phrase = [phr for phr in L.d(clause_list[0]) if F.function.v(phr) == 'Time'][0]
    
    # save it
    time_marker_data['markers'][marker] = {'count':count,
                                           'clauses':clause_list,
                                           'tense_cl_lists':tense_to_clause,
                                           'tense_counts':tense_cts,
                                           'tense_percents':tense_pct,
                                           'example_phrase': example_phrase
                                          }

# export the data
export_file = 'data/time_markers.pickle'

with open(export_file, 'wb') as of:
    pickle.dump(time_marker_data, of)
    
print('data exported!')
# Out:
# data exported!

# %% [markdown]
# ## Special Visualization
#
# Visualizing results of interest with a scatterplot.

# %%
# import time markers data
tm_data_file = 'data/time_markers.pickle'

# load data
with open(tm_data_file, 'rb') as infile:
    tm_data = pickle.load(infile)

# assign the data
markers = tm_data['markers']
top_markers = tm_data['top_markers']
stats_rows = tm_data['stats_rows']

# %%
# get x axis data for yiqtol 
x = [round(tense_percentages[marker]['impf'])
         for marker, count in top_markers]

# get y axis data for wayyiqtol
y = [round(tense_percentages[marker]['wayq'])
         for marker, count in top_markers]

# point color/sizes
t = np.arctan2(y,x) # point color based on angle of x/y
s = [150 for number in x] # point sizes

# size of the plot
plt.figure(figsize=(10,10))

# make it a scatter plot
plt.scatter(x, y, s=s, c=t, cmap='bwr')

# make ticks for the x/y axes
x_ticks = y_ticks = [n*5 for n in range(0,21)]
plt.xticks(x_ticks)
plt.yticks(y_ticks)
plt.ylabel('% wayyiqtol', color='red', fontsize='30')
plt.xlabel('% yiqtol', color='blue', fontsize='30')

# title
plt.title('Time Phrases Correlated with Wayyiqtol/Yiqtol', fontsize='20')

# annotate select time phrases

# showcase only extreme examples
showcased_time_phrases = set((x, y) for (x, y) in zip(x,y)
                                 if (x-y) > 60
                                 or (y-x) > 60
                                 or (x-y) < 4 and (y-x) < 4
                             )
# custom additions/subtractions to showcases
showcased_time_phrases.remove((71,7))
showcased_time_phrases.add((5, 60))

# map time marker data to their coordinates so they can be retrieved for annotations
xy_to_marker = collections.defaultdict(list)
for marker, count in top_markers:
    x = round(tense_percentages[marker]['impf'])
    y = round(tense_percentages[marker]['wayq'])
    xy_to_marker[(x,y)].append(marker)
    
    
# keep track of already-labeled markers to avoid label overlaps in yiqtols
already_y = []
    
for x, y in showcased_time_phrases:

    marker = xy_to_marker[(x,y)][0]
    
    hebrew_label = ' '.join([F.phono.v(w) for w 
                                in L.d(markers[marker]['example_phrase'], otype='word')])
    
    label=hebrew_label
    #label = (x,y)
    
    # fix overlapping labels
    xy_text = {(64, 0): (-20,40),
               (68, 0): (0,40),
               (75, 0): (20, 60),
               (79, 0): (80, 80),
               (82, 10): (0, 70),
               (0, 100): (110, -20),
               (83, 0): (80, 0),
               (82, 0): (80, 50),
               (5, 60): (140, 15),
               (0, 61): (80, 50),
               (31, 31): (120, -10)
              }
    
    plt.annotate(
                label,
                xy=(x,y), xytext= xy_text.get((x,y), (80, 20)),
                textcoords='offset points', ha='right', va='bottom',
                bbox=dict(boxstyle='round,pad=0.5', fc='white', alpha=0.5),
                arrowprops=dict(ec='black', arrowstyle = '->', connectionstyle='arc3,rad=0'),
                fontsize='12'
                )

# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)

# save/display plot
plt.savefig('visualizations/yiqtol_vs_wayyiqtol.png', dpi = 300)
plt.show()
